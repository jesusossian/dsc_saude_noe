# %%
import pandas as pd

# %%
df = pd.read_excel('../data/Base de dados Tese.xlsx')

# %%
df
# Out:
#                        Unnamed: 0                   Unnamed: 1  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2     Armazéns Regionais do Pais   Depositos Provinciais (DPM)
# 3         Armazem Regional do Sul                Maputo Cidade
# 4                             NaN            Maputo Provincia
# 5                             NaN                        Gaza
# 6                             NaN                   Inhambane
# 7                             NaN                          NaN
# 8   Armazem  Regional do  Centro                      Zambézia
# 9                             NaN                         Tete
# 10                            NaN                       Manica
# 11                            NaN                      Sofala
# 12                            NaN                          NaN
# 13     Armazem Regional do Norte                        Niassa
# ...
