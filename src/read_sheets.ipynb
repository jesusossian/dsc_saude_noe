# %%
import pandas as pd

# %%
df = pd.read_excel('../data/Base_de_dados_Tese.xlsx')

# %%
df
# Out:
#    Armazéns Regionais do Pais  Depositos Provinciais (DPM)  \
# 0                          Sul               Maputo Cidade
# 1                          Sul           Maputo Provincia
# 2                          Sul                       Gaza
# 3                          Sul                  Inhambane
# 4                       Centro                    Zambézia
# 5                       Centro                        Tete
# 6                       Centro                      Manica
# 7                       Centro                     Sofala
# 8                        Norte                      Niassa
# 9                        Norte                Cabo Delgado
# 10                       Norte                     Nampula
#
#     Unidades Sanitárias    Volume (m3) por Mês   Volume (m3) por Ano   \
# 0                      28                659.00               7908.00
# 1                     108                379.00               4548.00
# ...
